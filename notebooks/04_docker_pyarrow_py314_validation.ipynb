# %%
import sys
import pyarrow as pa
import pyarrow.dataset as ds
import pyarrow.parquet as pq
import pandas as pd
import duckdb

print(sys.version)
print("pyarrow:", pa.__version__)
print("dataset OK:", ds)
print("parquet OK:", pq)
print("pandas:", pd.__version__)
print("duckdb:", duckdb.__version__)
# Out:
# 3.14.5 (main, May 19 2026, 23:50:46) [GCC 14.2.0]
# pyarrow: 24.0.0
# dataset OK: <module 'pyarrow.dataset' from '/usr/local/lib/python3.14/site-packages/pyarrow/dataset.py'>
# parquet OK: <module 'pyarrow.parquet' from '/usr/local/lib/python3.14/site-packages/pyarrow/parquet/__init__.py'>
# pandas: 3.0.3
# duckdb: 1.5.3
